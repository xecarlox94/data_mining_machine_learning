# %%
import os

import pandas as pd



def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join("imgs", fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
dataset = pd.read_csv("dataset.csv")

dataset['goal_scored'].value_counts()
# Out:
# /opt/python3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (13,54,58,59,82,85,87,90,91,92,93,95,96,97,98,100,102,103,105,106,108,109,110,270,272,273,274,275,276,277,278,279,281,282,283,284,285) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  0    15961
#  1       98
# -1       32
# Name: goal_scored, dtype: int64

# %%
dataset['type_id'].value_counts()
# Out:
# 30    4370
# 42    3952
# 43    3556
# 17    1426
# 2      593
# 4      404
# 9      263
# 14     203
# 6      183
# 3      164
# 23     143
# 39     132
# 38     129
# 22     127
# 21     112
# 16     109
# 10      86
# 19      29
# 40      21
# 18      20
# 34      20
# 36      13
# 35      10
# 33       6
# 28       5
# 37       5
# 41       2
# 27       2
# 26       2
# 24       2
# 20       1
# 25       1
# Name: type_id, dtype: int64

# %%
dataset['type_name'].value_counts()
# Out:
# Pass                 4370
# Ball Receipt*        3952
# Carry                3556
# Pressure             1426
# Ball Recovery         593
# Duel                  404
# Clearance             263
# Dribble               203
# Block                 183
# Dispossessed          164
# Goal Keeper           143
# Dribbled Past         132
# Miscontrol            129
# Foul Committed        127
# Foul Won              112
# Shot                  109
# Interception           86
# Substitution           29
# Injury Stoppage        21
# Half Start             20
# Half End               20
# Tactical Shift         13
# Starting XI            10
# 50/50                   6
# Shield                  5
# Error                   5
# Referee Ball-Drop       2
# Player Off              2
# Player On               2
# Bad Behaviour           2
# Own Goal Against        1
# Own Goal For            1
# Name: type_name, dtype: int64

# %%
import utils 


dataset = utils.clean_dataframe(dataset)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16091 entries, 0 to 16090
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   type_name                        16091 non-null  object
#  1   delta_direct_angle               16091 non-null  float64
#  2   directness                       16091 non-null  float64
#  3   goal_scored                      16091 non-null  int64
#  4   opo_goal_angle                   16091 non-null  float64
#  5   opo_goal_distance                16091 non-null  float64
#  6   opo_team_mat_delta_direct_angle  16091 non-null  float64
#  7   opo_team_mat_directness          16091 non-null  float64
#  8   opo_team_mat_opo_goal_angle      16091 non-null  float64
#  9   opo_team_mat_own_goal_angle      16091 non-null  float64
#  10  opo_team_ses_delta_direct_angle  16091 non-null  float64
#  11  opo_team_ses_directness          16091 non-null  float64
#  12  opo_team_ses_opo_goal_angle      16091 non-null  float64
#  13  opo_team_ses_own_goal_angle      16091 non-null  float64
#  14  own_goal_angle                   16091 non-null  float64
#  15  own_goal_distance                16091 non-null  float64
#  16  own_team_mat_delta_direct_angle  16091 non-null  float64
#  17  own_team_mat_directness          16091 non-null  float64
#  18  own_team_mat_opo_goal_angle      16091 non-null  float64
#  19  own_team_mat_own_goal_angle      16091 non-null  float64
#  20  own_team_ses_delta_direct_angle  16091 non-null  float64
#  21  own_team_ses_directness          16091 non-null  float64
#  22  own_team_ses_opo_goal_angle      16091 non-null  float64
#  23  own_team_ses_own_goal_angle      16091 non-null  float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 2.9+ MB

# %%
dataset.describe()
# Out:
#        delta_direct_angle    directness   goal_scored  opo_goal_angle  \
# count        16091.000000  16091.000000  16091.000000    16091.000000
# mean             0.758935      0.688006      0.004102        0.002046
# std              0.786555      0.325070      0.089793        0.049518
# min              0.000000      0.000000     -1.000000        0.000000
# 25%              0.105085      0.392458      0.000000        0.000852
# 50%              0.519012      0.794626      0.000000        0.001041
# 75%              1.139729      1.000000      0.000000        0.001340
# max              3.141385      1.000000      1.000000        3.141545
#
#        opo_goal_distance  opo_team_mat_delta_direct_angle  \
# count       16091.000000                     16091.000000
# mean           66.444690                         0.452120
# std            26.758744                         0.224386
# min             0.000000                         0.000000
# 25%            46.631534                         0.423053
# 50%            66.212763                         0.510137
# 75%            86.004535                         0.564105
# max           122.413929                         2.240567
#
#        opo_team_mat_directness  opo_team_mat_opo_goal_angle  \
# count             16091.000000                 16091.000000
# mean                  0.616798                     0.004229
# std                   0.167674                     0.012700
# min                   0.131096                     0.000000
# 25%                   0.525722                     0.001215
# 50%                   0.578165                     0.001500
# 75%                   0.620532                     0.001954
# max                   1.000000                     0.158158
#
#        opo_team_mat_own_goal_angle  opo_team_ses_delta_direct_angle  ...  \
# count                 16091.000000                     16091.000000  ...
# mean                      0.001115                         0.275702  ...
# std                       0.000512                         0.411377  ...
# min                       0.000000                         0.000000  ...
# 25%                       0.001035                         0.000000  ...
# 50%                       0.001177                         0.097089  ...
# 75%                       0.001459                         0.408899  ...
# max                       0.002311                         3.069183  ...
#
#        own_goal_angle  own_goal_distance  own_team_mat_delta_direct_angle  \
# count    16091.000000       16091.000000                     16091.000000
# mean         0.001643          63.300099                         0.441318
# std          0.003187          28.235752                         0.216872
# min          0.000000           0.000000                         0.000000
# 25%          0.000877          43.006976                         0.379598
# 50%          0.001101          62.208761                         0.510169
# 75%          0.001491          84.105380                         0.563940
# max          0.099917         126.491106                         2.240567
#
#        own_team_mat_directness  own_team_mat_opo_goal_angle  \
# count             16091.000000                 16091.000000
# mean                  0.611179                     0.005872
# std                   0.174982                     0.015908
# min                   0.131096                     0.000000
# 25%                   0.515532                     0.001287
# 50%                   0.556932                     0.001606
# 75%                   0.620532                     0.002135
# max                   1.000000                     0.158158
#
#        own_team_mat_own_goal_angle  own_team_ses_delta_direct_angle  \
# count                 16091.000000                     16091.000000
# mean                      0.001043                         0.179376
# std                       0.000482                         0.333635
# min                       0.000000                         0.000000
# 25%                       0.000995                         0.000000
# 50%                       0.001143                         0.000000
# 75%                       0.001321                         0.258422
# max                       0.002311                         3.069183
#
#        own_team_ses_directness  own_team_ses_opo_goal_angle  \
# count             16091.000000                 16091.000000
# mean                  0.823963                     0.000789
# std                   0.289653                     0.001304
# min                   0.000000                     0.000000
# 25%                   0.686199                     0.000000
# 50%                   1.000000                     0.000000
# 75%                   1.000000                     0.001246
# max                   1.000000                     0.029266
#
#        own_team_ses_own_goal_angle
# count                 16091.000000
# mean                      0.000557
# std                       0.000962
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000938
# max                       0.009660
#
# [8 rows x 23 columns]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


fig = plt.figure()
dataset.hist(bins=50, figsize=(20, 15))

plt.show()

# %%
corr_matrix = dataset.corr()

corr_matrix['goal_scored'].sort_values(ascending=False)
# Out:
# goal_scored                        1.000000
# own_goal_distance                  0.107035
# opo_team_ses_own_goal_angle        0.080186
# opo_team_mat_own_goal_angle        0.078139
# opo_team_mat_delta_direct_angle    0.066150
# own_team_mat_delta_direct_angle    0.060240
# own_team_mat_own_goal_angle        0.055751
# own_team_ses_opo_goal_angle        0.054376
# own_team_ses_own_goal_angle        0.051855
# opo_team_ses_delta_direct_angle    0.037613
# directness                         0.029191
# own_team_ses_delta_direct_angle    0.017501
# opo_team_ses_opo_goal_angle        0.011074
# opo_team_mat_opo_goal_angle        0.004948
# opo_goal_angle                     0.002476
# own_team_mat_opo_goal_angle       -0.009426
# delta_direct_angle                -0.022192
# opo_team_ses_directness           -0.030988
# own_team_ses_directness           -0.068453
# own_team_mat_directness           -0.073523
# opo_team_mat_directness           -0.073623
# opo_goal_distance                 -0.106405
# own_goal_angle                    -0.111319
# Name: goal_scored, dtype: float64

# %%
alpha = 0.1

dataset.plot(kind="scatter", y="goal_scored", x="own_goal_distance", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="opo_team_ses_own_goal_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="opo_team_mat_own_goal_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="opo_team_mat_delta_direct_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="own_team_mat_delta_direct_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="own_team_mat_own_goal_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="own_team_ses_opo_goal_angle", alpha=alpha)
# Out:
# <AxesSubplot:xlabel='own_team_ses_opo_goal_angle', ylabel='goal_scored'>

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = [
    "own_goal_distance", 
    "opo_team_ses_own_goal_angle", 
    "opo_team_mat_own_goal_angle",
    "goal_scored"
]

scatter_matrix(dataset[attributes], figsize=(12, 8))

save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot
