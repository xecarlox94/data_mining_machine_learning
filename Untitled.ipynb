# %%
import pandas as pd


dataset = pd.read_csv("dataset.csv")

dataset['goal_scored'].value_counts()
# Out:
# /opt/python3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (13,54,58,59,82,85,87,90,91,92,93,95,96,97,98,100,102,103,105,106,108,109,110,270,272,273,274,275,276,277,278,279,281,282,283,284,285) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  0    15961
#  1       98
# -1       32
# Name: goal_scored, dtype: int64

# %%
dataset['type_id'].value_counts()
# Out:
# 30    4370
# 42    3952
# 43    3556
# 17    1426
# 2      593
# 4      404
# 9      263
# 14     203
# 6      183
# 3      164
# 23     143
# 39     132
# 38     129
# 22     127
# 21     112
# 16     109
# 10      86
# 19      29
# 40      21
# 18      20
# 34      20
# 36      13
# 35      10
# 33       6
# 28       5
# 37       5
# 41       2
# 27       2
# 26       2
# 24       2
# 20       1
# 25       1
# Name: type_id, dtype: int64

# %%
dataset['type_name'].value_counts()
# Out:
# Pass                 4370
# Ball Receipt*        3952
# Carry                3556
# Pressure             1426
# Ball Recovery         593
# Duel                  404
# Clearance             263
# Dribble               203
# Block                 183
# Dispossessed          164
# Goal Keeper           143
# Dribbled Past         132
# Miscontrol            129
# Foul Committed        127
# Foul Won              112
# Shot                  109
# Interception           86
# Substitution           29
# Injury Stoppage        21
# Half Start             20
# Half End               20
# Tactical Shift         13
# Starting XI            10
# 50/50                   6
# Shield                  5
# Error                   5
# Referee Ball-Drop       2
# Player Off              2
# Player On               2
# Bad Behaviour           2
# Own Goal Against        1
# Own Goal For            1
# Name: type_name, dtype: int64

# %%
cols = [
    "id",
    "period",
    "timestamp",
    "minute",
    "second",
    "duration",
    "type_id",
    #"type_name",
    "team_id",
    "team_name",
    "tactics_formation",
    "tactics_lineup",
    "related_events",
    "half_start_late_video_start",
    "location",
    "player_id",
    "player_name",
    "position_id",
    "position_name",
    "pass_recipient_id",
    "pass_recipient_name",
    "pass_length",
    "pass_angle",
    "pass_height_id",
    "pass_height_name",
    "pass_end_location",
    "pass_body_part_id",
    "pass_body_part_name",
    "pass_type_id",
    "pass_type_name",
    "carry_end_location",
    "pass_outcome_id",
    "pass_outcome_name",
    "ball_receipt_outcome_id",
    "ball_receipt_outcome_name",
    "under_pressure",
    "duel_type_id",
    "duel_type_name",
    "pass_aerial_won",
    "out",
    "clearance_right_foot",
    "clearance_body_part_id",
    "clearance_body_part_name",
    "counterpress",
    "duel_outcome_id",
    "duel_outcome_name",
    "interception_outcome_id",
    "interception_outcome_name",
    "pass_switch",
    "ball_recovery_recovery_failure",
    "dribble_outcome_id",
    "dribble_outcome_name",
    "off_camera",
    "pass_cross",
    "pass_inswinging",
    "pass_technique_id",
    "pass_technique_name",
    "clearance_head",
    "pass_straight",
    "miscontrol_aerial_won",
    "clearance_aerial_won",
    "shot_statsbomb_xg",                                               #?????????????? should I ???
    "shot_end_location",
    "shot_technique_id",
    "shot_technique_name",
    "shot_body_part_id",
    "shot_body_part_name",
    "shot_type_id",
    "shot_type_name",
    "shot_outcome_id",
    "shot_outcome_name",
    "shot_freeze_frame",
    "goalkeeper_end_location",
    "goalkeeper_position_id",
    "goalkeeper_position_name",
    "goalkeeper_type_id",
    "goalkeeper_type_name",
    "shot_first_time",
    "pass_through_ball",
    "goalkeeper_outcome_id",
    "goalkeeper_outcome_name",
    "clearance_left_foot",
    "pass_cut_back",
    "pass_assisted_shot_id",
    "pass_shot_assist",
    "pass_outswinging",
    "shot_key_pass_id",
    "foul_committed_offensive",
    "foul_won_defensive",
    "foul_committed_card_id",
    "foul_committed_card_name",
    "pass_goal_assist",
    "shot_deflected",
    "block_deflection",
    "goalkeeper_technique_id",
    "goalkeeper_technique_name",
    "block_offensive",
    "foul_committed_advantage",
    "foul_won_advantage",
    "substitution_outcome_id",
    "substitution_outcome_name",
    "substitution_replacement_id",
    "substitution_replacement_name",
    "foul_committed_penalty",
    "foul_committed_type_id",
    "foul_committed_type_name",
    "shot_one_on_one",
    "goalkeeper_body_part_id",
    "goalkeeper_body_part_name",
    "pass_deflected",
    "dribble_nutmeg",
    "match_id",
    "chain_index",
    #"delta_direct_angle",
    "delta_time",
    "direct_distance",
    #"directness",
    #"goal_scored",
    "indirect_distance",
    #"opo_goal_angle",
    "opo_goal_angle_absolute_variation",
    "opo_goal_angle_variation",
    "opo_goal_distance",
    "opo_goal_distance_absolute_variation",
    "opo_goal_distance_variation",
    #"opo_team_mat_delta_direct_angle",
    "opo_team_mat_delta_time",
    "opo_team_mat_direct_distance",
    #"opo_team_mat_directness",
    "opo_team_mat_indirect_distance",
    #"opo_team_mat_opo_goal_angle",
    "opo_team_mat_opo_goal_angle_absolute_variation",
    "opo_team_mat_opo_goal_distance",
    "opo_team_mat_opo_goal_distance_absolute_variation",
    #"opo_team_mat_own_goal_angle",
    "opo_team_mat_own_goal_angle_absolute_variation",
    "opo_team_mat_own_goal_distance",
    "opo_team_mat_own_goal_distance_absolute_variation",
    "opo_team_mat_percentage_carries_count",
    "opo_team_mat_percentage_carries_distance",
    "opo_team_mat_percentage_ground_passes_count",
    "opo_team_mat_percentage_ground_passes_distance",
    "opo_team_mat_percentage_high_passes_count",
    "opo_team_mat_percentage_high_passes_distance",
    "opo_team_mat_percentage_low_passes_count",
    "opo_team_mat_percentage_low_passes_distance",
    "opo_team_mat_percentage_passes_count",
    "opo_team_mat_percentage_passes_distance",
    "opo_team_mat_percentage_shots_count",
    "opo_team_mat_percentage_shots_distance",
    #"opo_team_ses_delta_direct_angle",
    "opo_team_ses_delta_time",
    "opo_team_ses_direct_distance",
    #"opo_team_ses_directness",
    "opo_team_ses_indirect_distance",
    #"opo_team_ses_opo_goal_angle",
    "opo_team_ses_opo_goal_angle_absolute_variation",
    "opo_team_ses_opo_goal_distance",
    "opo_team_ses_opo_goal_distance_absolute_variation",
    #"opo_team_ses_own_goal_angle",
    "opo_team_ses_own_goal_angle_absolute_variation",
    "opo_team_ses_own_goal_distance",
    "opo_team_ses_own_goal_distance_absolute_variation",
    "opo_team_ses_percentage_carries_count",
    "opo_team_ses_percentage_carries_distance",
    "opo_team_ses_percentage_ground_passes_count",
    "opo_team_ses_percentage_ground_passes_distance",
    "opo_team_ses_percentage_high_passes_count",
    "opo_team_ses_percentage_high_passes_distance",
    "opo_team_ses_percentage_low_passes_count",
    "opo_team_ses_percentage_low_passes_distance",
    "opo_team_ses_percentage_passes_count",
    "opo_team_ses_percentage_passes_distance",
    "opo_team_ses_percentage_shots_count",
    "opo_team_ses_percentage_shots_distance",
    #"own_goal_angle",
    "own_goal_angle_absolute_variation",
    "own_goal_angle_variation",
    "own_goal_distance",
    "own_goal_distance_absolute_variation",
    "own_goal_distance_variation",
    #"own_team_mat_delta_direct_angle",
    "own_team_mat_delta_time",
    "own_team_mat_direct_distance",
    #"own_team_mat_directness",
    "own_team_mat_indirect_distance",
    #"own_team_mat_opo_goal_angle",
    "own_team_mat_opo_goal_angle_absolute_variation",
    "own_team_mat_opo_goal_distance",
    "own_team_mat_opo_goal_distance_absolute_variation",
    #"own_team_mat_own_goal_angle",
    "own_team_mat_own_goal_angle_absolute_variation",
    "own_team_mat_own_goal_distance",
    "own_team_mat_own_goal_distance_absolute_variation",
    "own_team_mat_percentage_carries_count",
    "own_team_mat_percentage_carries_distance",
    "own_team_mat_percentage_ground_passes_count",
    "own_team_mat_percentage_ground_passes_distance",
    "own_team_mat_percentage_high_passes_count",
    "own_team_mat_percentage_high_passes_distance",
    "own_team_mat_percentage_low_passes_count",
    "own_team_mat_percentage_low_passes_distance",
    "own_team_mat_percentage_passes_count",
    "own_team_mat_percentage_passes_distance",
    "own_team_mat_percentage_shots_count",
    "own_team_mat_percentage_shots_distance",
    #"own_team_ses_delta_direct_angle",
    "own_team_ses_delta_time",
    "own_team_ses_direct_distance",
    #"own_team_ses_directness",
    "own_team_ses_indirect_distance",
    #"own_team_ses_opo_goal_angle",
    "own_team_ses_opo_goal_angle_absolute_variation",
    "own_team_ses_opo_goal_distance",
    "own_team_ses_opo_goal_distance_absolute_variation",
    #"own_team_ses_own_goal_angle",
    "own_team_ses_own_goal_angle_absolute_variation",
    "own_team_ses_own_goal_distance",
    "own_team_ses_own_goal_distance_absolute_variation",
    "own_team_ses_percentage_carries_count",
    "own_team_ses_percentage_carries_distance",
    "own_team_ses_percentage_ground_passes_count",
    "own_team_ses_percentage_ground_passes_distance",
    "own_team_ses_percentage_high_passes_count",
    "own_team_ses_percentage_high_passes_distance",
    "own_team_ses_percentage_low_passes_count",
    "own_team_ses_percentage_low_passes_distance",
    "own_team_ses_percentage_passes_count",
    "own_team_ses_percentage_passes_distance",
    "own_team_ses_percentage_shots_count",
    "own_team_ses_percentage_shots_distance",
    "percentage_carries_count",
    "percentage_carries_distance",
    "percentage_ground_passes_count",
    "percentage_ground_passes_distance",
    "percentage_high_passes_count",
    "percentage_high_passes_distance",
    "percentage_low_passes_count",
    "percentage_low_passes_distance",
    "percentage_passes_count",
    "percentage_passes_distance",
    "percentage_shots_count",
    "percentage_shots_distance",
    "prev_delta_time",
    "recover_delta_direct_angle",
    "recover_delta_time",
    "recover_direct_distance",
    "recover_directness",
    "recover_indirect_distance",
    "recover_opo_goal_angle_absolute_variation",
    "recover_opo_goal_angle_variation",
    "recover_opo_goal_distance_absolute_variation",
    "recover_opo_goal_distance_variation",
    "recover_own_goal_angle_absolute_variation",
    "recover_own_goal_angle_variation",
    "recover_own_goal_distance_absolute_variation",
    "recover_own_goal_distance_variation",
    "recover_percentage_carries_count",
    "recover_percentage_carries_distance",
    "recover_percentage_ground_passes_count",
    "recover_percentage_ground_passes_distance",
    "recover_percentage_high_passes_count",
    "recover_percentage_high_passes_distance",
    "recover_percentage_low_passes_count",
    "recover_percentage_low_passes_distance",
    "recover_percentage_passes_count",
    "recover_percentage_passes_distance",
    "recover_percentage_shots_count",
    "recover_percentage_shots_distance",
    "recover_prev_delta_time",
    "clearance_other",
    "50_50_outcome_id",
    "50_50_outcome_name",
    "dribble_overrun",
    "shot_aerial_won",
    "shot_saved_off_target",
    "goalkeeper_shot_saved_off_target",
    "pass_no_touch",
    "ball_recovery_offensive",
    "foul_won_penalty",
    "bad_behaviour_card_id",
    "bad_behaviour_card_name",
    "shot_saved_to_post",
    "goalkeeper_shot_saved_to_post",
    "block_save_block",
    "pass_miscommunication"
]

dataset = dataset.drop(cols, axis=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16091 entries, 0 to 16090
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   type_name                        16091 non-null  object
#  1   delta_direct_angle               16091 non-null  float64
#  2   directness                       16091 non-null  float64
#  3   goal_scored                      16091 non-null  int64
#  4   opo_goal_angle                   16091 non-null  float64
#  5   opo_team_mat_delta_direct_angle  16091 non-null  float64
#  6   opo_team_mat_directness          16091 non-null  float64
#  7   opo_team_mat_opo_goal_angle      16091 non-null  float64
#  8   opo_team_mat_own_goal_angle      16091 non-null  float64
#  9   opo_team_ses_delta_direct_angle  16091 non-null  float64
#  10  opo_team_ses_directness          16091 non-null  float64
#  11  opo_team_ses_opo_goal_angle      16091 non-null  float64
#  12  opo_team_ses_own_goal_angle      16091 non-null  float64
#  13  own_goal_angle                   16091 non-null  float64
#  14  own_team_mat_delta_direct_angle  16091 non-null  float64
#  15  own_team_mat_directness          16091 non-null  float64
#  16  own_team_mat_opo_goal_angle      16091 non-null  float64
#  17  own_team_mat_own_goal_angle      16091 non-null  float64
#  18  own_team_ses_delta_direct_angle  16091 non-null  float64
#  19  own_team_ses_directness          16091 non-null  float64
#  20  own_team_ses_opo_goal_angle      16091 non-null  float64
#  21  own_team_ses_own_goal_angle      16091 non-null  float64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 2.7+ MB

# %%
dataset.describe()
# Out:
#        delta_direct_angle    directness   goal_scored  opo_goal_angle  \
# count        16091.000000  16091.000000  16091.000000    16091.000000
# mean             0.758935      0.688006      0.004102        0.002046
# std              0.786555      0.325070      0.089793        0.049518
# min              0.000000      0.000000     -1.000000        0.000000
# 25%              0.105085      0.392458      0.000000        0.000852
# 50%              0.519012      0.794626      0.000000        0.001041
# 75%              1.139729      1.000000      0.000000        0.001340
# max              3.141385      1.000000      1.000000        3.141545
#
#        opo_team_mat_delta_direct_angle  opo_team_mat_directness  \
# count                     16091.000000             16091.000000
# mean                          0.452120                 0.616798
# std                           0.224386                 0.167674
# min                           0.000000                 0.131096
# 25%                           0.423053                 0.525722
# 50%                           0.510137                 0.578165
# 75%                           0.564105                 0.620532
# max                           2.240567                 1.000000
#
#        opo_team_mat_opo_goal_angle  opo_team_mat_own_goal_angle  \
# count                 16091.000000                 16091.000000
# mean                      0.004229                     0.001115
# std                       0.012700                     0.000512
# min                       0.000000                     0.000000
# 25%                       0.001215                     0.001035
# 50%                       0.001500                     0.001177
# 75%                       0.001954                     0.001459
# max                       0.158158                     0.002311
#
#        opo_team_ses_delta_direct_angle  opo_team_ses_directness  ...  \
# count                     16091.000000             16091.000000  ...
# mean                          0.275702                 0.776891  ...
# std                           0.411377                 0.293462  ...
# min                           0.000000                 0.000000  ...
# 25%                           0.000000                 0.588885  ...
# 50%                           0.097089                 0.967669  ...
# 75%                           0.408899                 1.000000  ...
# max                           3.069183                 1.000000  ...
#
#        opo_team_ses_own_goal_angle  own_goal_angle  \
# count                 16091.000000    16091.000000
# mean                      0.000794        0.001643
# std                       0.001046        0.003187
# min                       0.000000        0.000000
# 25%                       0.000000        0.000877
# 50%                       0.000795        0.001101
# 75%                       0.001086        0.001491
# max                       0.009722        0.099917
#
#        own_team_mat_delta_direct_angle  own_team_mat_directness  \
# count                     16091.000000             16091.000000
# mean                          0.441318                 0.611179
# std                           0.216872                 0.174982
# min                           0.000000                 0.131096
# 25%                           0.379598                 0.515532
# 50%                           0.510169                 0.556932
# 75%                           0.563940                 0.620532
# max                           2.240567                 1.000000
#
#        own_team_mat_opo_goal_angle  own_team_mat_own_goal_angle  \
# count                 16091.000000                 16091.000000
# mean                      0.005872                     0.001043
# std                       0.015908                     0.000482
# min                       0.000000                     0.000000
# 25%                       0.001287                     0.000995
# 50%                       0.001606                     0.001143
# 75%                       0.002135                     0.001321
# max                       0.158158                     0.002311
#
#        own_team_ses_delta_direct_angle  own_team_ses_directness  \
# count                     16091.000000             16091.000000
# mean                          0.179376                 0.823963
# std                           0.333635                 0.289653
# min                           0.000000                 0.000000
# 25%                           0.000000                 0.686199
# 50%                           0.000000                 1.000000
# 75%                           0.258422                 1.000000
# max                           3.069183                 1.000000
#
#        own_team_ses_opo_goal_angle  own_team_ses_own_goal_angle
# count                 16091.000000                 16091.000000
# mean                      0.000789                     0.000557
# std                       0.001304                     0.000962
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.001246                     0.000938
# max                       0.029266                     0.009660
#
# [8 rows x 21 columns]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


fig = plt.figure()
dataset.hist(bins=50, figsize=(20, 15))

plt.show()

# %%
corr_matrix = dataset.corr()

corr_matrix['goal_scored'].sort_values(ascending=False)
# Out:
# goal_scored                        1.000000
# opo_team_ses_own_goal_angle        0.080186
# opo_team_mat_own_goal_angle        0.078139
# opo_team_mat_delta_direct_angle    0.066150
# own_team_mat_delta_direct_angle    0.060240
# own_team_mat_own_goal_angle        0.055751
# own_team_ses_opo_goal_angle        0.054376
# own_team_ses_own_goal_angle        0.051855
# opo_team_ses_delta_direct_angle    0.037613
# directness                         0.029191
# own_team_ses_delta_direct_angle    0.017501
# opo_team_ses_opo_goal_angle        0.011074
# opo_team_mat_opo_goal_angle        0.004948
# opo_goal_angle                     0.002476
# own_team_mat_opo_goal_angle       -0.009426
# delta_direct_angle                -0.022192
# opo_team_ses_directness           -0.030988
# own_team_ses_directness           -0.068453
# own_team_mat_directness           -0.073523
# opo_team_mat_directness           -0.073623
# own_goal_angle                    -0.111319
# Name: goal_scored, dtype: float64

# %%
dataset.plot(kind="scatter", x="goal_scored", y="opo_team_mat_own_goal_angle", alpha=0.2)

dataset.plot(kind="scatter", x="goal_scored", y="own_team_ses_opo_goal_angle", alpha=0.2)

dataset.plot(kind="scatter", x="goal_scored", y="own_team_mat_own_goal_angle", alpha=0.2)

dataset.plot(kind="scatter", x="goal_scored", y="own_team_mat_delta_direct_angle", alpha=0.2)
# Out:
# <AxesSubplot:xlabel='goal_scored', ylabel='own_team_mat_delta_direct_angle'>
