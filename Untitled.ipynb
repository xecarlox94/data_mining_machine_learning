# %%
import os

import pandas as pd

import utils 


def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join("imgs", fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

    
dataset = pd.read_csv("dataset.csv")


dataset = utils.clean_dataframe(dataset)

#dataset = dataset[dataset['type_name'] == 'Shot']

for i in [22, 21, 19, 18, 34, 40, 27, 26, 25, 20, 41, 35, 36]:
    index_names = dataset[ 
        (dataset['type_id'] == i)
    ].index
    dataset.drop(index_names, inplace = True)

dataset['type_name'].value_counts()
# Out:
# /home/xecarlox/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (11,13,39,49,54,56,58,59,60,78,82,85,87,90,91,92,93,95,96,97,98,100,102,103,105,106,108,109,110,270,272,273,274,275,276,277,278) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Pass             1783
# Ball Receipt*    1603
# Carry            1361
# Pressure          654
# Ball Recovery     246
# Duel              196
# Clearance         114
# Dribble            82
# Block              78
# Dispossessed       77
# Goal Keeper        63
# Dribbled Past      53
# Shot               50
# Miscontrol         49
# Interception       30
# Shield              3
# 50/50               2
# Name: type_name, dtype: int64

# %%
dataset['type_id'].value_counts()
# Out:
# 30    1783
# 42    1603
# 43    1361
# 17     654
# 2      246
# 4      196
# 9      114
# 14      82
# 6       78
# 3       77
# 23      63
# 39      53
# 16      50
# 38      49
# 10      30
# 28       3
# 33       2
# Name: type_id, dtype: int64

# %%
corr_matrix = dataset.corr()

corr_matrix['goal_scored'].sort_values(ascending=False)
# Out:
# goal_scored                        1.000000
# opo_team_mat_own_goal_angle        0.088944
# own_goal_distance                  0.088400
# opo_team_ses_indirect_distance     0.084157
# own_team_mat_own_goal_distance     0.078331
# opo_team_mat_indirect_distance     0.077063
# opo_team_mat_opo_goal_distance     0.075110
# own_team_ses_opo_goal_angle        0.073534
# opo_team_mat_own_goal_distance     0.066394
# opo_team_ses_own_goal_distance     0.065086
# opo_team_ses_opo_goal_distance     0.064351
# own_team_mat_opo_goal_distance     0.063452
# own_team_mat_own_goal_angle        0.062124
# own_team_mat_delta_direct_angle    0.061835
# own_team_ses_indirect_distance     0.059643
# opo_team_mat_delta_direct_angle    0.058925
# own_team_ses_own_goal_distance     0.053060
# own_team_mat_indirect_distance     0.040231
# opo_team_ses_own_goal_angle        0.037291
# own_team_ses_own_goal_angle        0.029004
# type_id                            0.026159
# opo_team_ses_delta_direct_angle    0.024292
# directness                         0.018794
# opo_team_ses_opo_goal_angle        0.017551
# own_team_ses_opo_goal_distance     0.017232
# own_team_ses_delta_direct_angle    0.015955
# opo_team_mat_opo_goal_angle        0.008780
# opo_goal_angle                     0.001108
# delta_direct_angle                -0.010159
# own_team_mat_opo_goal_angle       -0.016008
# indirect_distance                 -0.016959
# opo_team_ses_directness           -0.038764
# own_goal_angle                    -0.041250
# own_team_ses_directness           -0.047066
# own_team_mat_directness           -0.060546
# opo_team_mat_directness           -0.064028
# opo_goal_distance                 -0.096752
# Name: goal_scored, dtype: float64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6444 entries, 4 to 6579
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   type_id                          6444 non-null   int64
#  1   type_name                        6444 non-null   object
#  2   delta_direct_angle               6444 non-null   float64
#  3   directness                       6444 non-null   float64
#  4   goal_scored                      6444 non-null   int64
#  5   indirect_distance                6444 non-null   float64
#  6   opo_goal_angle                   6444 non-null   float64
#  7   opo_goal_distance                6444 non-null   float64
#  8   opo_team_mat_delta_direct_angle  6444 non-null   float64
#  9   opo_team_mat_directness          6444 non-null   float64
#  10  opo_team_mat_indirect_distance   6444 non-null   float64
#  11  opo_team_mat_opo_goal_angle      6444 non-null   float64
#  12  opo_team_mat_opo_goal_distance   6444 non-null   float64
#  13  opo_team_mat_own_goal_angle      6444 non-null   float64
#  14  opo_team_mat_own_goal_distance   6444 non-null   float64
#  15  opo_team_ses_delta_direct_angle  6444 non-null   float64
#  16  opo_team_ses_directness          6444 non-null   float64
#  17  opo_team_ses_indirect_distance   6444 non-null   float64
#  18  opo_team_ses_opo_goal_angle      6444 non-null   float64
#  19  opo_team_ses_opo_goal_distance   6444 non-null   float64
#  20  opo_team_ses_own_goal_angle      6444 non-null   float64
#  21  opo_team_ses_own_goal_distance   6444 non-null   float64
#  22  own_goal_angle                   6444 non-null   float64
#  23  own_goal_distance                6444 non-null   float64
#  24  own_team_mat_delta_direct_angle  6444 non-null   float64
#  25  own_team_mat_directness          6444 non-null   float64
#  26  own_team_mat_indirect_distance   6444 non-null   float64
#  27  own_team_mat_opo_goal_angle      6444 non-null   float64
#  28  own_team_mat_opo_goal_distance   6444 non-null   float64
#  29  own_team_mat_own_goal_angle      6444 non-null   float64
#  30  own_team_mat_own_goal_distance   6444 non-null   float64
#  31  own_team_ses_delta_direct_angle  6444 non-null   float64
#  32  own_team_ses_directness          6444 non-null   float64
#  33  own_team_ses_indirect_distance   6444 non-null   float64
#  34  own_team_ses_opo_goal_angle      6444 non-null   float64
#  35  own_team_ses_opo_goal_distance   6444 non-null   float64
#  36  own_team_ses_own_goal_angle      6444 non-null   float64
#  37  own_team_ses_own_goal_distance   6444 non-null   float64
# dtypes: float64(35), int64(2), object(1)
# memory usage: 1.9+ MB

# %%
dataset.describe()
# Out:
#            type_id  delta_direct_angle   directness  goal_scored  \
# count  6444.000000         6444.000000  6444.000000  6444.000000
# mean     31.228119            0.742745     0.701541     0.003259
# std      13.016785            0.794287     0.320184     0.083509
# min       2.000000            0.000000     0.000000    -1.000000
# 25%      30.000000            0.085869     0.421090     0.000000
# 50%      30.000000            0.484061     0.831631     0.000000
# 75%      42.000000            1.131996     1.000000     0.000000
# max      43.000000            3.141385     1.000000     1.000000
#
#        indirect_distance  opo_goal_angle  opo_goal_distance  \
# count        6444.000000     6444.000000        6444.000000
# mean           53.380279        0.002263          66.398136
# std            61.255242        0.055327          25.886033
# min             0.000000       -0.000000           2.716616
# 25%             9.372300        0.000866          47.194596
# 50%            32.399436        0.001056          65.842994
# 75%            77.489159        0.001360          85.406864
# max           492.035707        3.141545         120.331708
#
#        opo_team_mat_delta_direct_angle  opo_team_mat_directness  \
# count                      6444.000000              6444.000000
# mean                          0.458861                 0.630521
# std                           0.229002                 0.157160
# min                           0.000000                 0.434436
# 25%                           0.438141                 0.537228
# 50%                           0.507016                 0.579325
# 75%                           0.549191                 0.624963
# max                           2.240567                 1.000000
#
#        opo_team_mat_indirect_distance  ...  own_team_mat_opo_goal_distance  \
# count                     6444.000000  ...                     6444.000000
# mean                        42.992911  ...                       51.202098
# std                         20.591738  ...                       21.552721
# min                          0.000000  ...                        0.000000
# 25%                         40.909328  ...                       54.055372
# 50%                         44.776244  ...                       57.000294
# 75%                         51.014289  ...                       62.824256
# max                        166.983351  ...                      101.839923
#
#        own_team_mat_own_goal_angle  own_team_mat_own_goal_distance  \
# count                  6444.000000                     6444.000000
# mean                      0.001080                       62.692381
# std                       0.000466                       26.091254
# min                       0.000000                        0.000000
# 25%                       0.001097                       66.717273
# 50%                       0.001174                       70.682962
# 75%                       0.001396                       77.363147
# max                       0.002311                       96.840496
#
#        own_team_ses_delta_direct_angle  own_team_ses_directness  \
# count                      6444.000000              6444.000000
# mean                          0.184601                 0.845564
# std                           0.333988                 0.269259
# min                           0.000000                 0.000000
# 25%                           0.000000                 0.769095
# 50%                           0.000000                 1.000000
# 75%                           0.262657                 1.000000
# max                           2.799675                 1.000000
#
#        own_team_ses_indirect_distance  own_team_ses_opo_goal_angle  \
# count                     6444.000000                  6444.000000
# mean                        24.599151                     0.000781
# std                         40.558550                     0.001351
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                         42.371041                     0.001186
# max                        285.074760                     0.029266
#
#        own_team_ses_opo_goal_distance  own_team_ses_own_goal_angle  \
# count                     6444.000000                  6444.000000
# mean                        24.306638                     0.000525
# std                         31.017636                     0.000799
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                         48.644757                     0.000951
# max                        116.060889                     0.009231
#
#        own_team_ses_own_goal_distance
# count                     6444.000000
# mean                        33.840133
# std                         40.541340
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                         75.156678
# max                        126.491106
#
# [8 rows x 37 columns]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


fig = plt.figure()
dataset.hist(bins=50, figsize=(20, 15))

plt.show()

# %%
alpha = 0.1

dataset.plot(kind="scatter", y="goal_scored", x="own_goal_distance", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="opo_team_ses_own_goal_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="opo_team_mat_own_goal_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="opo_team_mat_delta_direct_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="own_team_mat_delta_direct_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="own_team_mat_own_goal_angle", alpha=alpha)

dataset.plot(kind="scatter", y="goal_scored", x="own_team_ses_opo_goal_angle", alpha=alpha)
# Out:
# <AxesSubplot:xlabel='own_team_ses_opo_goal_angle', ylabel='goal_scored'>

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = [
    "own_goal_distance", 
    "opo_team_ses_own_goal_angle", 
    "opo_team_mat_own_goal_angle",
    "goal_scored"
]

scatter_matrix(dataset[attributes], figsize=(12, 8))

save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot
